# %%
import nltk
from nltk.tokenize import word_tokenize

# # Download tokenizer data (first time only)
# nltk.download('punkt_tab')

text = "I am learning NLP. It is very interesting!"

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['I', 'am', 'learning', 'NLP', '.', 'It', 'is', 'very', 'interesting', '!']

# %%
text.split()
# Out:
# ['I', 'am', 'learning', 'NLP.', 'It', 'is', 'very', 'interesting!']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["study", "studies", "studying", "studied"]
for word in words:
    print(word, "******", stemmer.stem(word))
# Out:
# study ****** studi
# studies ****** studi
# studying ****** studi
# studied ****** studi

# %%
# Lemitisation

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
words = ["studies", "running", "better", "went"]
for word in words:
    print(word, "→", lemmatizer.lemmatize(word,pos = 'v')) # here you can alter a part of spech
# Out:
# studies → study
# running → run
# better → better
# went → go
